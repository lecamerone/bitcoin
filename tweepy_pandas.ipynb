# %%
import tweepy
import pandas as pd
import json

access_token = "58376679-pYJnz2QvnR2rgSjVdYzoozNJpYq3ISVlaI9JymKqL"
access_token_secret = "Y8Luqi2xPw10FylGUuiql1mLnxXy1K2IMt0ErptcEUg3y"
consumer_key = "jyKuaf6p71nAIVvmPz41kNdSE"
consumer_secret = "XFq8lZtheDSIDfaoCgywDxGD1ZCF3vpGra8vpwmTbrgBD866hM"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

status_list = api.user_timeline("lecamerone")
status = status_list[0]
json_str = json.dumps(status._json)

# %%
len(status_list)
# Out:
# 20

# %%
status_list = api.user_timeline(user_handler)
status = status_list[0]
json_str = json.dumps(status._json)
# Out:
# tweepy.models.ResultSet

# %%
results = []

#Get the first 5000 items based on the search query
for tweet in tweepy.Cursor(api.search, q='bitcoin').items(500):
    results.append(tweet)

# Verify the number of items returned
print (len(results))
# Out:
# 500

# %%
def toDataFrame(tweets):

    DataSet = pd.DataFrame()

    DataSet['tweetID'] = [tweet.id for tweet in tweets]
    DataSet['tweetText'] = [tweet.text for tweet in tweets]
    DataSet['tweetRetweetCt'] = [tweet.retweet_count for tweet 
    in tweets]
    DataSet['tweetFavoriteCt'] = [tweet.favorite_count for tweet 
    in tweets]
    DataSet['tweetSource'] = [tweet.source for tweet in tweets]
    DataSet['tweetCreated'] = [tweet.created_at for tweet in tweets]


    DataSet['userID'] = [tweet.user.id for tweet in tweets]
    DataSet['userScreen'] = [tweet.user.screen_name for tweet 
    in tweets]
    DataSet['userName'] = [tweet.user.name for tweet in tweets]
    DataSet['userCreateDt'] = [tweet.user.created_at for tweet 
    in tweets]
    DataSet['userDesc'] = [tweet.user.description for tweet in tweets]
    DataSet['userFollowerCt'] = [tweet.user.followers_count for tweet 
    in tweets]
    DataSet['userFriendsCt'] = [tweet.user.friends_count for tweet 
    in tweets]
    DataSet['userLocation'] = [tweet.user.location for tweet in tweets]
    DataSet['userTimezone'] = [tweet.user.time_zone for tweet 
    in tweets]

    return DataSet

#Pass the tweets list to the above function to create a DataFrame
DataSet = toDataFrame(results)

# %%
DataSet
# Out:
#                 tweetID                                          tweetText  \
# 0    914809454247411712  RT @crowdholding: #blockchain and how it is qu...
# 1    914809447926648832  Bitcoin Exchange BTCC Brings Chinese Trading t...
# 2    914809446798434304  RT @marckenigsberg: A despot and terrible fisc...
# 3    914809440653725696  RT @YVerif: System Operations explained by Ver...
# 4    914809439177383936  RT @zerohedge: Bitcoin Surges Above $4400 As W...
# 5    914809434098094081  Bitcoin Exchange BTCC Brings Chinese Trading t...
# 6    914809431803568129  RT @SpectreAI: Bitcoin challenges Bank of Russ...
# 7    914809428117016576  RT @zerohedge: Bitcoin Surges Above $4400 As W...
# 8    914809427596840960  RT @onlycrypto: This is 1 Day Bitcoin Chart. H...
# 9    914809426422435840  RT @DutchCrypto87: Be patient!!! \n#crypto #cr...
# 10   914809426124709888  СУММА ДЖЕКПОТА   314.52 USD\n#Bitcoin #Dogecoi...
# ...
